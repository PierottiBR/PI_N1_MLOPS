# %%
import pandas as pd
import ast
import re

# %%
rows = []

with open (r'D:\PROGRAMACION\PROYECTOS\PROYECTOINDIVIDIAL1\PROYECTOINDIVUDUAL\DATASETS\australian_user_reviews.json', encoding='utf-8') as f:
    for line in f.readlines():
        rows.append(ast.literal_eval(line))

df_reviews_csv = pd.DataFrame(rows)

# %%
df_reviews_csv = pd.json_normalize(rows, record_path='reviews', meta=['user_id','user_url'])

# %%
df_reviews_csv
# Out:
#                                   funny                     posted  \
# 0                                         Posted November 5, 2011.
# 1                                            Posted July 15, 2011.
# 2                                           Posted April 21, 2011.
# 3                                            Posted June 24, 2014.
# 4                                        Posted September 8, 2013.
# ...                                 ...                        ...
# 59300                                              Posted July 10.
# 59301                                               Posted July 8.
# 59302  1 person found this review funny             Posted July 3.
# 59303                                              Posted July 20.
# 59304                                               Posted July 2.
#
#       last_edited item_id                                          helpful  \
# 0                    1250                                   No ratings yet
# ...

# %%
df_reviews_csv = df_reviews_csv.drop(columns=['funny', 'last_edited', 'helpful', 'user_url'])

# %%
df_reviews_csv['posted'] = df_reviews_csv['posted'].str.replace('Posted', '')
df_reviews_csv['posted'] = df_reviews_csv['posted'].str.replace('.', '')
df_reviews_csv['posted'] = df_reviews_csv['posted'].str.strip()

# %%
pattern = r"[^\w\s':]+"
df_reviews_csv['review'] = df_reviews_csv['review'].apply(lambda x: re.sub(pattern, '', x))

# %%
df_reviews_csv.drop_duplicates(subset=['user_id','item_id','review'],inplace=True)

# %%
df_reviews_csv
# Out:
#                   posted item_id  recommend  \
# 0       November 5, 2011    1250       True
# 1          July 15, 2011   22200       True
# 2         April 21, 2011   43110       True
# 3          June 24, 2014  251610       True
# 4      September 8, 2013  227300       True
# ...                  ...     ...        ...
# 59300            July 10      70       True
# 59301             July 8  362890       True
# 59302             July 3  273110       True
# 59303            July 20     730       True
# 59304             July 2     440       True
#
#                                                   review            user_id
# 0      Simple yet with great replayability In my opin...  76561197970982479
# 1                    It's unique and worth a playthrough  76561197970982479
# 2      Great atmosphere The gunplay can be a bit chun...  76561197970982479
# 3      I know what you think when you see this title ...            js41637
# ...

# %%
df_reviews_csv.to_csv(r'D:\PROGRAMACION\PROYECTOS\PROYECTOINDIVIDIAL1\PROYECTOINDIVUDUAL\ARCHIVOSCSVLIMPIOS\userreviews.csv', index=False)

# %%
df_reviews_csv.to_parquet(r'D:\PROGRAMACION\PROYECTOS\PROYECTOINDIVIDIAL1\PROYECTOINDIVUDUAL\ARCHIVOSCSVLIMPIOS\PARQUETS\userreviews.parquet')
